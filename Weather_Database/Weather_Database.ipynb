# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e375aa9a4a9ddd52c9c12cf5f7a13010

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | glendive
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | saldanha
# Processing Record 8 of Set 1 | almunecar
# Processing Record 9 of Set 1 | saskylakh
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | mahebourg
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | nikolskoye
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | banikoara
# Processing Record 17 of Set 1 | sabang
# Processing Record 18 of Set 1 | ekhabi
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | wenling
# Processing Record 21 of Set 1 | vanavara
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | sao felix do xingu
# Processing Record 25 of Set 1 | bengkulu
# Processing Record 26 of Set 1 | ilulissat
# Processing Record 27 of Set 1 | pringsewu
# Processing Record 28 of Set 1 | alugan
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | homa bay
# Processing Record 31 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | afgoye
# City not found. Skipping...
# Processing Record 34 of Set 1 | seydi
# Processing Record 35 of Set 1 | halifax
# Processing Record 36 of Set 1 | ust-ilimsk
# Processing Record 37 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 1 | lompoc
# Processing Record 39 of Set 1 | asau
# Processing Record 40 of Set 1 | souillac
# Processing Record 41 of Set 1 | castro
# Processing Record 42 of Set 1 | lauria
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | chuy
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 1 | thompson
# Processing Record 1 of Set 2 | mezen
# Processing Record 2 of Set 2 | metlika
# Processing Record 3 of Set 2 | carnarvon
# Processing Record 4 of Set 2 | bilibino
# Processing Record 5 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 2 | xichang
# Processing Record 7 of Set 2 | clyde river
# Processing Record 8 of Set 2 | tasiilaq
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | lagoa
# Processing Record 11 of Set 2 | miles city
# Processing Record 12 of Set 2 | muros
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | ushtobe
# Processing Record 15 of Set 2 | brownsville
# Processing Record 16 of Set 2 | baghdad
# Processing Record 17 of Set 2 | mantua
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | guerrero negro
# Processing Record 20 of Set 2 | mumford
# Processing Record 21 of Set 2 | esna
# Processing Record 22 of Set 2 | kodinsk
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | iwanai
# Processing Record 25 of Set 2 | kodiak
# Processing Record 26 of Set 2 | kidal
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | trat
# Processing Record 29 of Set 2 | kruisfontein
# Processing Record 30 of Set 2 | chaman
# Processing Record 31 of Set 2 | sur
# Processing Record 32 of Set 2 | aripuana
# Processing Record 33 of Set 2 | los llanos de aridane
# Processing Record 34 of Set 2 | qaanaaq
# Processing Record 35 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 36 of Set 2 | sioux lookout
# Processing Record 37 of Set 2 | monrovia
# Processing Record 38 of Set 2 | nanortalik
# Processing Record 39 of Set 2 | hailar
# Processing Record 40 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 2 | tiksi
# Processing Record 42 of Set 2 | winneba
# Processing Record 43 of Set 2 | kahului
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | bonthe
# Processing Record 46 of Set 2 | mahina
# Processing Record 47 of Set 2 | khatanga
# Processing Record 48 of Set 2 | bobon
# Processing Record 49 of Set 2 | christchurch
# Processing Record 50 of Set 2 | fort smith
# Processing Record 1 of Set 3 | kemalpasa
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | saint-philippe
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | fortuna
# Processing Record 6 of Set 3 | bluff
# Processing Record 7 of Set 3 | pulandian
# Processing Record 8 of Set 3 | conde
# Processing Record 9 of Set 3 | stokmarknes
# Processing Record 10 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 3 | ambilobe
# Processing Record 12 of Set 3 | nuuk
# Processing Record 13 of Set 3 | maceio
# Processing Record 14 of Set 3 | alexandria
# Processing Record 15 of Set 3 | muscle shoals
# Processing Record 16 of Set 3 | nantucket
# Processing Record 17 of Set 3 | dzhebariki-khaya
# Processing Record 18 of Set 3 | petrivka
# Processing Record 19 of Set 3 | thinadhoo
# Processing Record 20 of Set 3 | birjand
# Processing Record 21 of Set 3 | varciorog
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | nanakuli
# Processing Record 24 of Set 3 | jamestown
# Processing Record 25 of Set 3 | tura
# Processing Record 26 of Set 3 | east london
# Processing Record 27 of Set 3 | pangody
# Processing Record 28 of Set 3 | channel-port aux basques
# Processing Record 29 of Set 3 | tarakan
# Processing Record 30 of Set 3 | san vicente
# Processing Record 31 of Set 3 | hofn
# Processing Record 32 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 3 | anshun
# Processing Record 34 of Set 3 | nazareno
# Processing Record 35 of Set 3 | ewa beach
# Processing Record 36 of Set 3 | omsukchan
# Processing Record 37 of Set 3 | uige
# Processing Record 38 of Set 3 | butaritari
# Processing Record 39 of Set 3 | herat
# Processing Record 40 of Set 3 | asaba
# Processing Record 41 of Set 3 | lewistown
# Processing Record 42 of Set 3 | esperance
# Processing Record 43 of Set 3 | atbasar
# Processing Record 44 of Set 3 | yumen
# Processing Record 45 of Set 3 | hazorasp
# Processing Record 46 of Set 3 | indianola
# Processing Record 47 of Set 3 | bubaque
# Processing Record 48 of Set 3 | piacabucu
# Processing Record 49 of Set 3 | turukhansk
# Processing Record 50 of Set 3 | chokwe
# Processing Record 1 of Set 4 | mazamari
# Processing Record 2 of Set 4 | kiunga
# Processing Record 3 of Set 4 | lorengau
# Processing Record 4 of Set 4 | huangchuan
# Processing Record 5 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 4 | talnakh
# Processing Record 7 of Set 4 | ponta do sol
# Processing Record 8 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 4 | sitka
# Processing Record 10 of Set 4 | mattawa
# Processing Record 11 of Set 4 | tsienyane
# City not found. Skipping...
# Processing Record 12 of Set 4 | san cristobal
# Processing Record 13 of Set 4 | miandrivazo
# Processing Record 14 of Set 4 | puri
# Processing Record 15 of Set 4 | babanka
# Processing Record 16 of Set 4 | gweta
# Processing Record 17 of Set 4 | buala
# Processing Record 18 of Set 4 | agadez
# Processing Record 19 of Set 4 | sri aman
# Processing Record 20 of Set 4 | moundsville
# Processing Record 21 of Set 4 | nisia floresta
# Processing Record 22 of Set 4 | portland
# Processing Record 23 of Set 4 | mayo
# Processing Record 24 of Set 4 | kisarazu
# Processing Record 25 of Set 4 | norman wells
# Processing Record 26 of Set 4 | oyek
# Processing Record 27 of Set 4 | chernyshevskiy
# Processing Record 28 of Set 4 | aleksandrov gay
# Processing Record 29 of Set 4 | dudinka
# Processing Record 30 of Set 4 | burica
# City not found. Skipping...
# Processing Record 31 of Set 4 | leningradskiy
# Processing Record 32 of Set 4 | puerto madryn
# Processing Record 33 of Set 4 | mananjary
# Processing Record 34 of Set 4 | flinders
# Processing Record 35 of Set 4 | richards bay
# Processing Record 36 of Set 4 | puerto del rosario
# Processing Record 37 of Set 4 | riyadh
# Processing Record 38 of Set 4 | barrow
# Processing Record 39 of Set 4 | ostersund
# Processing Record 40 of Set 4 | northam
# Processing Record 41 of Set 4 | lasa
# Processing Record 42 of Set 4 | nizhniy odes
# Processing Record 43 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 4 | san vicente de canete
# Processing Record 45 of Set 4 | seoul
# Processing Record 46 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 4 | trincomalee
# Processing Record 48 of Set 4 | slave lake
# Processing Record 49 of Set 4 | horta
# Processing Record 50 of Set 4 | santa isabel do rio negro
# Processing Record 1 of Set 5 | victoria
# Processing Record 2 of Set 5 | udimskiy
# Processing Record 3 of Set 5 | faanui
# Processing Record 4 of Set 5 | nanzhou
# Processing Record 5 of Set 5 | touros
# Processing Record 6 of Set 5 | husavik
# Processing Record 7 of Set 5 | hamilton
# Processing Record 8 of Set 5 | provideniya
# Processing Record 9 of Set 5 | port elizabeth
# Processing Record 10 of Set 5 | geraldton
# Processing Record 11 of Set 5 | bathsheba
# Processing Record 12 of Set 5 | vardo
# Processing Record 13 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 5 | pangnirtung
# Processing Record 15 of Set 5 | gidam
# Processing Record 16 of Set 5 | ghazipur
# Processing Record 17 of Set 5 | coahuayana
# Processing Record 18 of Set 5 | weinan
# Processing Record 19 of Set 5 | rocha
# Processing Record 20 of Set 5 | buzmeyin
# Processing Record 21 of Set 5 | seinajoki
# Processing Record 22 of Set 5 | hirara
# Processing Record 23 of Set 5 | cabo san lucas
# Processing Record 24 of Set 5 | kirakira
# Processing Record 25 of Set 5 | san quintin
# Processing Record 26 of Set 5 | borogontsy
# Processing Record 27 of Set 5 | ondjiva
# Processing Record 28 of Set 5 | nemuro
# Processing Record 29 of Set 5 | springdale
# Processing Record 30 of Set 5 | tlaxiaca
# City not found. Skipping...
# Processing Record 31 of Set 5 | okha
# Processing Record 32 of Set 5 | mul
# Processing Record 33 of Set 5 | iqaluit
# Processing Record 34 of Set 5 | smithers
# Processing Record 35 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 5 | harrismith
# Processing Record 37 of Set 5 | vestmanna
# Processing Record 38 of Set 5 | vuktyl
# Processing Record 39 of Set 5 | dicabisagan
# Processing Record 40 of Set 5 | banyo
# Processing Record 41 of Set 5 | sahuaripa
# Processing Record 42 of Set 5 | lebu
# Processing Record 43 of Set 5 | acarau
# Processing Record 44 of Set 5 | vilcun
# Processing Record 45 of Set 5 | bandarbeyla
# Processing Record 46 of Set 5 | namibe
# Processing Record 47 of Set 5 | nichinan
# Processing Record 48 of Set 5 | port lincoln
# Processing Record 49 of Set 5 | cruzeiro do sul
# Processing Record 50 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 6 | sabinas hidalgo
# Processing Record 2 of Set 6 | prince rupert
# Processing Record 3 of Set 6 | tuatapere
# Processing Record 4 of Set 6 | opuwo
# Processing Record 5 of Set 6 | thunder bay
# Processing Record 6 of Set 6 | naryan-mar
# Processing Record 7 of Set 6 | narsaq
# Processing Record 8 of Set 6 | puerto escondido
# Processing Record 9 of Set 6 | key west
# Processing Record 10 of Set 6 | kushiro
# Processing Record 11 of Set 6 | solnechnyy
# Processing Record 12 of Set 6 | ural
# Processing Record 13 of Set 6 | meulaboh
# Processing Record 14 of Set 6 | novozybkov
# Processing Record 15 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 16 of Set 6 | malanje
# Processing Record 17 of Set 6 | makakilo city
# Processing Record 18 of Set 6 | kalmunai
# Processing Record 19 of Set 6 | bonavista
# Processing Record 20 of Set 6 | salvador
# Processing Record 21 of Set 6 | shenjiamen
# Processing Record 22 of Set 6 | ponnani
# Processing Record 23 of Set 6 | georgetown
# Processing Record 24 of Set 6 | alta floresta
# Processing Record 25 of Set 6 | mende
# Processing Record 26 of Set 6 | lethem
# Processing Record 27 of Set 6 | sukhothai
# Processing Record 28 of Set 6 | arraial do cabo
# Processing Record 29 of Set 6 | pisco
# Processing Record 30 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 31 of Set 6 | guerrero
# Processing Record 32 of Set 6 | pingliang
# Processing Record 33 of Set 6 | fez
# Processing Record 34 of Set 6 | ostrovnoy
# Processing Record 35 of Set 6 | kaitangata
# Processing Record 36 of Set 6 | evensk
# Processing Record 37 of Set 6 | debre zeyit
# Processing Record 38 of Set 6 | eydhafushi
# Processing Record 39 of Set 6 | sorland
# Processing Record 40 of Set 6 | klaksvik
# Processing Record 41 of Set 6 | bethel
# Processing Record 42 of Set 6 | victor harbor
# Processing Record 43 of Set 6 | maykain
# City not found. Skipping...
# Processing Record 44 of Set 6 | innisfail
# Processing Record 45 of Set 6 | ayan
# Processing Record 46 of Set 6 | khrebtovaya
# Processing Record 47 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 6 | bardiyah
# Processing Record 49 of Set 6 | yichang
# Processing Record 50 of Set 6 | roxana
# Processing Record 1 of Set 7 | malkangiri
# Processing Record 2 of Set 7 | simpang
# Processing Record 3 of Set 7 | namatanai
# Processing Record 4 of Set 7 | mirador
# Processing Record 5 of Set 7 | lima
# Processing Record 6 of Set 7 | shubarshi
# Processing Record 7 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 8 of Set 7 | aksu
# Processing Record 9 of Set 7 | sinnamary
# Processing Record 10 of Set 7 | pevek
# Processing Record 11 of Set 7 | kamenka
# Processing Record 12 of Set 7 | kloulklubed
# Processing Record 13 of Set 7 | chapais
# Processing Record 14 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 7 | vila velha
# Processing Record 16 of Set 7 | chengde
# Processing Record 17 of Set 7 | paita
# Processing Record 18 of Set 7 | fairbanks
# Processing Record 19 of Set 7 | cidreira
# Processing Record 20 of Set 7 | waipawa
# Processing Record 21 of Set 7 | lata
# Processing Record 22 of Set 7 | maarianhamina
# Processing Record 23 of Set 7 | sobolevo
# Processing Record 24 of Set 7 | baruun-urt
# Processing Record 25 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 26 of Set 7 | constitucion
# Processing Record 27 of Set 7 | kimbe
# Processing Record 28 of Set 7 | mar del plata
# Processing Record 29 of Set 7 | ellensburg
# Processing Record 30 of Set 7 | santa maria del oro
# Processing Record 31 of Set 7 | klyuchi
# Processing Record 32 of Set 7 | inuvik
# Processing Record 33 of Set 7 | gusev
# Processing Record 34 of Set 7 | preobrazheniye
# Processing Record 35 of Set 7 | harper
# Processing Record 36 of Set 7 | sept-iles
# Processing Record 37 of Set 7 | upata
# Processing Record 38 of Set 7 | bintulu
# Processing Record 39 of Set 7 | emba
# Processing Record 40 of Set 7 | wagar
# Processing Record 41 of Set 7 | sharjah
# Processing Record 42 of Set 7 | suba
# Processing Record 43 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 7 | ipameri
# Processing Record 45 of Set 7 | cap malheureux
# Processing Record 46 of Set 7 | ancud
# Processing Record 47 of Set 7 | odweyne
# Processing Record 48 of Set 7 | tautira
# Processing Record 49 of Set 7 | itarema
# Processing Record 50 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 1 of Set 8 | airai
# Processing Record 2 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 3 of Set 8 | mabaruma
# Processing Record 4 of Set 8 | oistins
# Processing Record 5 of Set 8 | la romana
# Processing Record 6 of Set 8 | binzhou
# Processing Record 7 of Set 8 | wheeling
# Processing Record 8 of Set 8 | jishou
# Processing Record 9 of Set 8 | ambovombe
# Processing Record 10 of Set 8 | severo-kurilsk
# Processing Record 11 of Set 8 | moron
# Processing Record 12 of Set 8 | oakdale
# Processing Record 13 of Set 8 | dicamay
# Processing Record 14 of Set 8 | belyy yar
# Processing Record 15 of Set 8 | cherskiy
# Processing Record 16 of Set 8 | olafsvik
# Processing Record 17 of Set 8 | batagay
# Processing Record 18 of Set 8 | port macquarie
# Processing Record 19 of Set 8 | tuy hoa
# Processing Record 20 of Set 8 | bereda
# Processing Record 21 of Set 8 | yuzhnyy
# Processing Record 22 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 23 of Set 8 | jalu
# Processing Record 24 of Set 8 | ust-kulom
# Processing Record 25 of Set 8 | deputatskiy
# Processing Record 26 of Set 8 | nocupetaro
# Processing Record 27 of Set 8 | tzucacab
# Processing Record 28 of Set 8 | midland
# Processing Record 29 of Set 8 | grand gaube
# Processing Record 30 of Set 8 | hopelchen
# Processing Record 31 of Set 8 | hay river
# Processing Record 32 of Set 8 | kavieng
# Processing Record 33 of Set 8 | janauba
# Processing Record 34 of Set 8 | magadan
# Processing Record 35 of Set 8 | kargasok
# Processing Record 36 of Set 8 | hambantota
# Processing Record 37 of Set 8 | bartica
# Processing Record 38 of Set 8 | gambela
# Processing Record 39 of Set 8 | usinsk
# Processing Record 40 of Set 8 | butembo
# Processing Record 41 of Set 8 | milos
# Processing Record 42 of Set 8 | san policarpo
# Processing Record 43 of Set 8 | moree
# Processing Record 44 of Set 8 | oranjemund
# Processing Record 45 of Set 8 | vredendal
# Processing Record 46 of Set 8 | epe
# Processing Record 47 of Set 8 | mandalgovi
# Processing Record 48 of Set 8 | naze
# Processing Record 49 of Set 8 | aasiaat
# Processing Record 50 of Set 8 | miri
# Processing Record 1 of Set 9 | toora-khem
# Processing Record 2 of Set 9 | anadyr
# Processing Record 3 of Set 9 | kudat
# Processing Record 4 of Set 9 | mount gambier
# Processing Record 5 of Set 9 | te anau
# Processing Record 6 of Set 9 | buraydah
# Processing Record 7 of Set 9 | buxar
# Processing Record 8 of Set 9 | pokosnoye
# Processing Record 9 of Set 9 | kano
# Processing Record 10 of Set 9 | port augusta
# Processing Record 11 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 9 | moerai
# Processing Record 13 of Set 9 | sao filipe
# Processing Record 14 of Set 9 | fare
# Processing Record 15 of Set 9 | gawler
# Processing Record 16 of Set 9 | maldonado
# Processing Record 17 of Set 9 | humaita
# Processing Record 18 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 9 | kvam
# Processing Record 20 of Set 9 | nelson bay
# Processing Record 21 of Set 9 | vila franca do campo
# Processing Record 22 of Set 9 | guadalupe y calvo
# Processing Record 23 of Set 9 | gaozhou
# Processing Record 24 of Set 9 | coihaique
# Processing Record 25 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 9 | straumen
# Processing Record 27 of Set 9 | the pas
# Processing Record 28 of Set 9 | vostok
# Processing Record 29 of Set 9 | gornopravdinsk
# Processing Record 30 of Set 9 | marsa matruh
# Processing Record 31 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 9 | palencia
# Processing Record 33 of Set 9 | hukuntsi
# Processing Record 34 of Set 9 | coquimbo
# Processing Record 35 of Set 9 | goba
# Processing Record 36 of Set 9 | henties bay
# Processing Record 37 of Set 9 | schleswig
# Processing Record 38 of Set 9 | grindavik
# Processing Record 39 of Set 9 | broken hill
# Processing Record 40 of Set 9 | labuan
# Processing Record 41 of Set 9 | mulege
# Processing Record 42 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 9 | ilhabela
# Processing Record 44 of Set 9 | ahipara
# Processing Record 45 of Set 9 | batemans bay
# Processing Record 46 of Set 9 | quelimane
# Processing Record 47 of Set 9 | nyagan
# Processing Record 48 of Set 9 | port hardy
# Processing Record 49 of Set 9 | kitgum
# Processing Record 50 of Set 9 | santa marta
# Processing Record 1 of Set 10 | hami
# Processing Record 2 of Set 10 | gurupa
# Processing Record 3 of Set 10 | pacific grove
# Processing Record 4 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 10 | simao
# Processing Record 6 of Set 10 | kishi
# Processing Record 7 of Set 10 | quatre cocos
# Processing Record 8 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 10 | paralimni
# Processing Record 10 of Set 10 | gannan
# Processing Record 11 of Set 10 | stonewall
# Processing Record 12 of Set 10 | olinda
# Processing Record 13 of Set 10 | baishishan
# Processing Record 14 of Set 10 | itaituba
# Processing Record 15 of Set 10 | gizo
# Processing Record 16 of Set 10 | luderitz
# Processing Record 17 of Set 10 | kavaratti
# Processing Record 18 of Set 10 | abu kamal
# Processing Record 19 of Set 10 | rio verde de mato grosso
# Processing Record 20 of Set 10 | jiexiu
# Processing Record 21 of Set 10 | uni
# Processing Record 22 of Set 10 | dwarka
# Processing Record 23 of Set 10 | bambanglipuro
# Processing Record 24 of Set 10 | xapuri
# Processing Record 25 of Set 10 | naron
# Processing Record 26 of Set 10 | vallenar
# Processing Record 27 of Set 10 | sijunjung
# Processing Record 28 of Set 10 | gushikawa
# Processing Record 29 of Set 10 | porto walter
# Processing Record 30 of Set 10 | maryville
# Processing Record 31 of Set 10 | margate
# Processing Record 32 of Set 10 | hasaki
# Processing Record 33 of Set 10 | pimentel
# Processing Record 34 of Set 10 | alice springs
# Processing Record 35 of Set 10 | kirn
# Processing Record 36 of Set 10 | belaya gora
# Processing Record 37 of Set 10 | imperia
# Processing Record 38 of Set 10 | purranque
# Processing Record 39 of Set 10 | isangel
# Processing Record 40 of Set 10 | bouna
# Processing Record 41 of Set 10 | kieta
# Processing Record 42 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 43 of Set 10 | chifeng
# Processing Record 44 of Set 10 | buta
# Processing Record 45 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 46 of Set 10 | half moon bay
# Processing Record 47 of Set 10 | guntur
# Processing Record 48 of Set 10 | jawhar
# Processing Record 49 of Set 10 | rio bueno
# Processing Record 50 of Set 10 | petatlan
# Processing Record 1 of Set 11 | les cayes
# Processing Record 2 of Set 11 | doha
# Processing Record 3 of Set 11 | praia
# Processing Record 4 of Set 11 | dinsor
# City not found. Skipping...
# Processing Record 5 of Set 11 | bullhead city
# Processing Record 6 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 11 | mehamn
# Processing Record 8 of Set 11 | kesennuma
# City not found. Skipping...
# Processing Record 9 of Set 11 | taoudenni
# Processing Record 10 of Set 11 | karratha
# Processing Record 11 of Set 11 | raga
# Processing Record 12 of Set 11 | samarai
# Processing Record 13 of Set 11 | kupang
# Processing Record 14 of Set 11 | nador
# Processing Record 15 of Set 11 | haines junction
# Processing Record 16 of Set 11 | zhuanghe
# Processing Record 17 of Set 11 | kiama
# Processing Record 18 of Set 11 | chase
# Processing Record 19 of Set 11 | boende
# Processing Record 20 of Set 11 | rudnogorsk
# Processing Record 21 of Set 11 | roebourne
# Processing Record 22 of Set 11 | upala
# Processing Record 23 of Set 11 | carauari
# Processing Record 24 of Set 11 | sistranda
# Processing Record 25 of Set 11 | srednekolymsk
# Processing Record 26 of Set 11 | huarmey
# Processing Record 27 of Set 11 | tiznit
# Processing Record 28 of Set 11 | sechura
# Processing Record 29 of Set 11 | vestmannaeyjar
# Processing Record 30 of Set 11 | veles
# Processing Record 31 of Set 11 | trinidad
# Processing Record 32 of Set 11 | amasia
# Processing Record 33 of Set 11 | alofi
# Processing Record 34 of Set 11 | xingyi
# Processing Record 35 of Set 11 | kumluca
# Processing Record 36 of Set 11 | chokurdakh
# Processing Record 37 of Set 11 | necochea
# Processing Record 38 of Set 11 | flin flon
# Processing Record 39 of Set 11 | toyooka
# Processing Record 40 of Set 11 | caravelas
# Processing Record 41 of Set 11 | sao jose da coroa grande
# Processing Record 42 of Set 11 | henderson
# Processing Record 43 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 44 of Set 11 | chumikan
# Processing Record 45 of Set 11 | ponta delgada
# Processing Record 46 of Set 11 | hargeysa
# Processing Record 47 of Set 11 | campbell river
# Processing Record 48 of Set 11 | manoel urbano
# Processing Record 49 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 50 of Set 11 | tadine
# Processing Record 1 of Set 12 | vila
# Processing Record 2 of Set 12 | kemijarvi
# Processing Record 3 of Set 12 | saint-francois
# Processing Record 4 of Set 12 | forbes
# Processing Record 5 of Set 12 | katsuura
# Processing Record 6 of Set 12 | rio branco
# Processing Record 7 of Set 12 | abha
# Processing Record 8 of Set 12 | minsk
# Processing Record 9 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 12 | krasnoselkup
# Processing Record 11 of Set 12 | vao
# Processing Record 12 of Set 12 | malakal
# Processing Record 13 of Set 12 | jacareacanga
# Processing Record 14 of Set 12 | dunedin
# Processing Record 15 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 12 | leshukonskoye
# Processing Record 17 of Set 12 | kulhudhuffushi
# Processing Record 18 of Set 12 | rabo de peixe
# Processing Record 19 of Set 12 | wanning
# Processing Record 20 of Set 12 | zadar
# Processing Record 21 of Set 12 | fountain hills
# Processing Record 22 of Set 12 | kaspiyskiy
# Processing Record 23 of Set 12 | tessalit
# Processing Record 24 of Set 12 | robertsganj
# Processing Record 25 of Set 12 | kargil
# Processing Record 26 of Set 12 | roald
# Processing Record 27 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 12 | khuzhir
# Processing Record 29 of Set 12 | kasempa
# Processing Record 30 of Set 12 | auki
# Processing Record 31 of Set 12 | ambunti
# Processing Record 32 of Set 12 | soyo
# Processing Record 33 of Set 12 | lodja
# Processing Record 34 of Set 12 | longyearbyen
# Processing Record 35 of Set 12 | kununurra
# Processing Record 36 of Set 12 | buchanan
# Processing Record 37 of Set 12 | muisne
# Processing Record 38 of Set 12 | new castle
# Processing Record 39 of Set 12 | cefalu
# Processing Record 40 of Set 12 | port hawkesbury
# Processing Record 41 of Set 12 | mawlaik
# Processing Record 42 of Set 12 | labrea
# Processing Record 43 of Set 12 | pochutla
# Processing Record 44 of Set 12 | ternate
# Processing Record 45 of Set 12 | freetown
# Processing Record 46 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 12 | axim
# Processing Record 48 of Set 12 | yar-sale
# Processing Record 49 of Set 12 | ust-tsilma
# Processing Record 50 of Set 12 | shelburne
# Processing Record 1 of Set 13 | jimo
# Processing Record 2 of Set 13 | changli
# Processing Record 3 of Set 13 | college
# Processing Record 4 of Set 13 | labytnangi
# Processing Record 5 of Set 13 | iskateley
# Processing Record 6 of Set 13 | santa cruz
# Processing Record 7 of Set 13 | baykit
# Processing Record 8 of Set 13 | ksenyevka
# City not found. Skipping...
# Processing Record 9 of Set 13 | shestakovo
# Processing Record 10 of Set 13 | marquette
# Processing Record 11 of Set 13 | ginda
# Processing Record 12 of Set 13 | the valley
# Processing Record 13 of Set 13 | genhe
# Processing Record 14 of Set 13 | laguna
# Processing Record 15 of Set 13 | martinsville
# Processing Record 16 of Set 13 | port blair
# Processing Record 17 of Set 13 | port-gentil
# Processing Record 18 of Set 13 | san borja
# Processing Record 19 of Set 13 | mingaora
# Processing Record 20 of Set 13 | presidente dutra
# Processing Record 21 of Set 13 | adrar
# Processing Record 22 of Set 13 | mogadishu
# Processing Record 23 of Set 13 | isla mujeres
# Processing Record 24 of Set 13 | pokhara
# Processing Record 25 of Set 13 | balakhninskiy
# Processing Record 26 of Set 13 | berdigestyakh
# Processing Record 27 of Set 13 | paratinga
# Processing Record 28 of Set 13 | wattegama
# Processing Record 29 of Set 13 | papara
# Processing Record 30 of Set 13 | linguere
# Processing Record 31 of Set 13 | roma
# Processing Record 32 of Set 13 | fort nelson
# Processing Record 33 of Set 13 | honiara
# Processing Record 34 of Set 13 | barcelona
# Processing Record 35 of Set 13 | elizabeth city
# Processing Record 36 of Set 13 | shache
# Processing Record 37 of Set 13 | tres lagoas
# Processing Record 38 of Set 13 | gera
# Processing Record 39 of Set 13 | puro
# Processing Record 40 of Set 13 | viedma
# Processing Record 41 of Set 13 | yelizovo
# Processing Record 42 of Set 13 | sumbe
# Processing Record 43 of Set 13 | kungurtug
# Processing Record 44 of Set 13 | ilheus
# Processing Record 45 of Set 13 | ketchikan
# Processing Record 46 of Set 13 | inirida
# Processing Record 47 of Set 13 | llanes
# Processing Record 48 of Set 13 | port victoria
# Processing Record 49 of Set 13 | santa fe
# Processing Record 50 of Set 13 | mahenge
# Processing Record 1 of Set 14 | katherine
# Processing Record 2 of Set 14 | kuusamo
# Processing Record 3 of Set 14 | kabalo
# Processing Record 4 of Set 14 | ixtapa
# Processing Record 5 of Set 14 | katunki
# City not found. Skipping...
# Processing Record 6 of Set 14 | maloarkhangelsk
# Processing Record 7 of Set 14 | dalbandin
# Processing Record 8 of Set 14 | bournemouth
# Processing Record 9 of Set 14 | suket
# Processing Record 10 of Set 14 | thap khlo
# Processing Record 11 of Set 14 | russell
# Processing Record 12 of Set 14 | san patricio
# Processing Record 13 of Set 14 | yulara
# Processing Record 14 of Set 14 | santiago del estero
# Processing Record 15 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 16 of Set 14 | arauca
# Processing Record 17 of Set 14 | hoshangabad
# Processing Record 18 of Set 14 | lhuntshi
# City not found. Skipping...
# Processing Record 19 of Set 14 | nha trang
# Processing Record 20 of Set 14 | ouango
# Processing Record 21 of Set 14 | rawson
# Processing Record 22 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 14 | komsomolskiy
# Processing Record 24 of Set 14 | sola
# Processing Record 25 of Set 14 | merauke
# Processing Record 26 of Set 14 | okhotsk
# Processing Record 27 of Set 14 | karasjok
# Processing Record 28 of Set 14 | varfurile
# Processing Record 29 of Set 14 | gavrilovka vtoraya
# Processing Record 30 of Set 14 | anage
# Processing Record 31 of Set 14 | gilroy
# Processing Record 32 of Set 14 | gasa
# Processing Record 33 of Set 14 | huilong
# Processing Record 34 of Set 14 | morondava
# Processing Record 35 of Set 14 | virden
# Processing Record 36 of Set 14 | crowley
# Processing Record 37 of Set 14 | birsk
# Processing Record 38 of Set 14 | coatepec
# Processing Record 39 of Set 14 | acapulco
# Processing Record 40 of Set 14 | charagua
# Processing Record 41 of Set 14 | balanacan
# Processing Record 42 of Set 14 | hrebinka
# Processing Record 43 of Set 14 | rangpur
# Processing Record 44 of Set 14 | camacha
# Processing Record 45 of Set 14 | veydelevka
# Processing Record 46 of Set 14 | makarov
# Processing Record 47 of Set 14 | labuhan
# Processing Record 48 of Set 14 | samana
# Processing Record 49 of Set 14 | walvis bay
# Processing Record 50 of Set 14 | amot
# Processing Record 1 of Set 15 | male
# Processing Record 2 of Set 15 | magna
# Processing Record 3 of Set 15 | shizunai
# Processing Record 4 of Set 15 | torbay
# Processing Record 5 of Set 15 | flic en flac
# Processing Record 6 of Set 15 | gamba
# Processing Record 7 of Set 15 | gat
# Processing Record 8 of Set 15 | pemangkat
# Processing Record 9 of Set 15 | eina
# Processing Record 10 of Set 15 | montepuez
# Processing Record 11 of Set 15 | rafai
# Processing Record 12 of Set 15 | baoshan
# Processing Record 13 of Set 15 | rundu
# Processing Record 14 of Set 15 | luanda
# Processing Record 15 of Set 15 | buin
# Processing Record 16 of Set 15 | gebre guracha
# Processing Record 17 of Set 15 | baza
# Processing Record 18 of Set 15 | dobryanka
# Processing Record 19 of Set 15 | baraboo
# Processing Record 20 of Set 15 | grants pass
# Processing Record 21 of Set 15 | port hedland
# Processing Record 22 of Set 15 | salalah
# Processing Record 23 of Set 15 | abu jubayhah
# City not found. Skipping...
# Processing Record 24 of Set 15 | pitkyaranta
# Processing Record 25 of Set 15 | tenenkou
# Processing Record 26 of Set 15 | saint-leu
# Processing Record 27 of Set 15 | wahiawa
# Processing Record 28 of Set 15 | egvekinot
# Processing Record 29 of Set 15 | nago
# Processing Record 30 of Set 15 | gondar
# Processing Record 31 of Set 15 | roseau
# Processing Record 32 of Set 15 | mega
# Processing Record 33 of Set 15 | dubbo
# Processing Record 34 of Set 15 | byron bay
# Processing Record 35 of Set 15 | svetlyy
# Processing Record 36 of Set 15 | yinchuan
# Processing Record 37 of Set 15 | alamogordo
# Processing Record 38 of Set 15 | awbari
# Processing Record 39 of Set 15 | calbuco
# Processing Record 40 of Set 15 | ust-ishim
# Processing Record 41 of Set 15 | new ulm
# Processing Record 42 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 43 of Set 15 | novyy urengoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(5)
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ushuaia -54.80  -68.30     46.40        75          75       23.04
# 1     Glendive  47.11 -104.71     62.60        36           1        9.17
# 2    Busselton -33.65  115.33     61.00        51           0       15.90
# 3  Tuktoyaktuk  69.45 -133.04      3.20        71          20       14.99
# 4      Rikitea -23.12 -134.97     74.55        69          20       12.71
#
#   Country Current Description
# 0      AR         shower rain
# 1      US           clear sky
# 2      AU           clear sky
# 3      CA          few clouds
# 4      PF          few clouds

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ushuaia      AR -54.80  -68.30     46.40        75          75
# 1         Glendive      US  47.11 -104.71     62.60        36           1
# 2        Busselton      AU -33.65  115.33     61.00        51           0
# 3      Tuktoyaktuk      CA  69.45 -133.04      3.20        71          20
# 4          Rikitea      PF -23.12 -134.97     74.55        69          20
# ..             ...     ...    ...     ...       ...       ...         ...
# 681         Awbari      LY  26.59   12.78     63.18        37          33
# 682        Calbuco      CL -41.77  -73.13     51.80        76          20
# 683      Ust-Ishim      RU  57.69   71.17     33.58        93          98
# 684        New Ulm      US  44.31  -94.46     60.80        41           1
# 685  Novyy Urengoy      RU  66.08   76.63      2.16        94          72
#
#      Wind Speed Current Description
# 0         23.04         shower rain
# 1          9.17           clear sky
# 2         15.90           clear sky
# 3         14.99          few clouds
# 4         12.71          few clouds
# ..          ...                 ...
# 681        6.76    scattered clouds
# 682        8.05          few clouds
# 683        7.14     overcast clouds
# 684        5.37           clear sky
# 685       12.62       broken clouds
#
# [686 rows x 9 columns]

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
